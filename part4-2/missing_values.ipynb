# %%
import pandas as pd
import numpy as np

df = pd.read_csv("csv_files/combined_customers.csv")

# 결측치 탐지
print(df.isnull())  # 각 셀별로 결측치 여부 확인
print("\n결측치 개수:")
print(df.isnull().sum())
# Out:
#      customer_id   name    age  email  join_date
# 0          False  False   True  False      False
# 1          False  False   True  False      False
# 2          False  False   True  False      False
# 3          False  False   True  False      False
# 4          False  False   True  False      False
# ..           ...    ...    ...    ...        ...
# 495        False  False  False  False      False
# 496        False  False  False  False      False
# 497        False  False  False  False      False
# 498        False  False  False  False      False
# 499        False  False  False  False      False
#
# [500 rows x 5 columns]
#
# 결측치 개수:
# customer_id     0
# name            0
# age            22
# email          22
# join_date       0
# dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# 결측치 시각화를 위한 히트맵
df = pd.read_csv("csv_files/combined_customers.csv")

plt.figure(figsize=(8, 4))
sns.heatmap(df.isnull(), cbar=True, cmap='viridis')
plt.title('missing values')
plt.show()

# %%
import pandas as pd

df = pd.read_csv("csv_files/combined_customers.csv")
df['age'].fillna(0, inplace=True)
print(df)
# Out:
#      customer_id         name   age                    email  \
# 0              1    Customer1   NaN    customer1@example.com
# 1              2    Customer2   NaN    customer2@example.com
# 2              3    Customer3   NaN    customer3@example.com
# 3              4    Customer4   NaN    customer4@example.com
# 4              5    Customer5   NaN    customer5@example.com
# ..           ...          ...   ...                      ...
# 495          396  Customer396  54.0  customer396@example.com
# 496          397  Customer397  57.0  customer397@example.com
# 497          398  Customer398  68.0  customer398@example.com
# 498          399  Customer399  29.0  customer399@example.com
# 499          400  Customer400  57.0  customer400@example.com
#
#                       join_date
# 0    2023-01-27 06:52:22.275679
# 1    2023-07-15 06:52:22.275698
# 2    2023-01-24 06:52:22.275704
# 3    2023-03-25 06:52:22.275709
# 4    2023-03-25 06:52:22.275713
# ..                          ...
# 495  2023-02-09 06:54:12.151607
# 496  2023-03-25 06:54:12.151613
# 497  2023-02-19 06:54:12.151618
# 498  2023-07-18 06:54:12.151624
# 499  2023-01-22 06:54:12.151629
#
# [500 rows x 5 columns]
#      customer_id         name   age                    email  \
# 0              1    Customer1   0.0    customer1@example.com
# 1              2    Customer2   0.0    customer2@example.com
# 2              3    Customer3   0.0    customer3@example.com
# 3              4    Customer4   0.0    customer4@example.com
# 4              5    Customer5   0.0    customer5@example.com
# ..           ...          ...   ...                      ...
# 495          396  Customer396  54.0  customer396@example.com
# 496          397  Customer397  57.0  customer397@example.com
# 497          398  Customer398  68.0  customer398@example.com
# 498          399  Customer399  29.0  customer399@example.com
# 499          400  Customer400  57.0  customer400@example.com
#
#                       join_date
# 0    2023-01-27 06:52:22.275679
# 1    2023-07-15 06:52:22.275698
# 2    2023-01-24 06:52:22.275704
# 3    2023-03-25 06:52:22.275709
# 4    2023-03-25 06:52:22.275713
# ..                          ...
# 495  2023-02-09 06:54:12.151607
# 496  2023-03-25 06:54:12.151613
# 497  2023-02-19 06:54:12.151618
# 498  2023-07-18 06:54:12.151624
# 499  2023-01-22 06:54:12.151629
#
# [500 rows x 5 columns]
# /var/folders/dg/k946k57108n2bklvf_jw_3y80000gq/T/ipykernel_34263/1949473598.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['age'].fillna(0, inplace=True)

# %%
import pandas as pd

df = pd.read_csv("csv_files/combined_customers.csv")
df['age'].fillna(df["age"].mean(), inplace=True)
print(df)
# Out:
#      customer_id         name        age                    email  \
# 0              1    Customer1  44.472803    customer1@example.com
# 1              2    Customer2  44.472803    customer2@example.com
# 2              3    Customer3  44.472803    customer3@example.com
# 3              4    Customer4  44.472803    customer4@example.com
# 4              5    Customer5  44.472803    customer5@example.com
# ..           ...          ...        ...                      ...
# 495          396  Customer396  54.000000  customer396@example.com
# 496          397  Customer397  57.000000  customer397@example.com
# 497          398  Customer398  68.000000  customer398@example.com
# 498          399  Customer399  29.000000  customer399@example.com
# 499          400  Customer400  57.000000  customer400@example.com
#
#                       join_date
# 0    2023-01-27 06:52:22.275679
# 1    2023-07-15 06:52:22.275698
# 2    2023-01-24 06:52:22.275704
# 3    2023-03-25 06:52:22.275709
# 4    2023-03-25 06:52:22.275713
# ..                          ...
# 495  2023-02-09 06:54:12.151607
# 496  2023-03-25 06:54:12.151613
# 497  2023-02-19 06:54:12.151618
# 498  2023-07-18 06:54:12.151624
# 499  2023-01-22 06:54:12.151629
#
# [500 rows x 5 columns]
# /var/folders/dg/k946k57108n2bklvf_jw_3y80000gq/T/ipykernel_34263/433433815.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['age'].fillna(df["age"].mean(), inplace=True)

# %%
import pandas as pd

df = pd.read_csv("csv_files/combined_customers.csv")
df['age'].fillna(df["age"].median(), inplace=True)
print(df)
# Out:
#      customer_id         name   age                    email  \
# 0              1    Customer1  45.5    customer1@example.com
# 1              2    Customer2  45.5    customer2@example.com
# 2              3    Customer3  45.5    customer3@example.com
# 3              4    Customer4  45.5    customer4@example.com
# 4              5    Customer5  45.5    customer5@example.com
# ..           ...          ...   ...                      ...
# 495          396  Customer396  54.0  customer396@example.com
# 496          397  Customer397  57.0  customer397@example.com
# 497          398  Customer398  68.0  customer398@example.com
# 498          399  Customer399  29.0  customer399@example.com
# 499          400  Customer400  57.0  customer400@example.com
#
#                       join_date
# 0    2023-01-27 06:52:22.275679
# 1    2023-07-15 06:52:22.275698
# 2    2023-01-24 06:52:22.275704
# 3    2023-03-25 06:52:22.275709
# 4    2023-03-25 06:52:22.275713
# ..                          ...
# 495  2023-02-09 06:54:12.151607
# 496  2023-03-25 06:54:12.151613
# 497  2023-02-19 06:54:12.151618
# 498  2023-07-18 06:54:12.151624
# 499  2023-01-22 06:54:12.151629
#
# [500 rows x 5 columns]
# /var/folders/dg/k946k57108n2bklvf_jw_3y80000gq/T/ipykernel_34263/2667649640.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['age'].fillna(df["age"].median(), inplace=True)

# %%
import pandas as pd

df = pd.read_csv("csv_files/combined_customers.csv")
print(df["age"].mode())
df['age'].fillna(df["age"].mode()[0], inplace=True)
print(df)
# Out:
# 0    59.0
# Name: age, dtype: float64
#      customer_id         name   age                    email  \
# 0              1    Customer1  59.0    customer1@example.com
# 1              2    Customer2  59.0    customer2@example.com
# 2              3    Customer3  59.0    customer3@example.com
# 3              4    Customer4  59.0    customer4@example.com
# 4              5    Customer5  59.0    customer5@example.com
# ..           ...          ...   ...                      ...
# 495          396  Customer396  54.0  customer396@example.com
# 496          397  Customer397  57.0  customer397@example.com
# 497          398  Customer398  68.0  customer398@example.com
# 498          399  Customer399  29.0  customer399@example.com
# 499          400  Customer400  57.0  customer400@example.com
#
#                       join_date
# 0    2023-01-27 06:52:22.275679
# 1    2023-07-15 06:52:22.275698
# 2    2023-01-24 06:52:22.275704
# 3    2023-03-25 06:52:22.275709
# 4    2023-03-25 06:52:22.275713
# ..                          ...
# 495  2023-02-09 06:54:12.151607
# 496  2023-03-25 06:54:12.151613
# 497  2023-02-19 06:54:12.151618
# 498  2023-07-18 06:54:12.151624
# 499  2023-01-22 06:54:12.151629
#
# [500 rows x 5 columns]
# /var/folders/dg/k946k57108n2bklvf_jw_3y80000gq/T/ipykernel_34263/3477713749.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['age'].fillna(df["age"].mode()[0], inplace=True)

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# 결측치 시각화를 위한 히트맵

df = pd.read_csv("csv_files/combined_customers.csv")
df['age'].fillna(method="ffill",inplace=True)
plt.figure(figsize=(8, 4))
sns.heatmap(df.isnull(), cbar=True, cmap='viridis')
plt.title('missing values')
plt.show()
# Out:
# /var/folders/dg/k946k57108n2bklvf_jw_3y80000gq/T/ipykernel_34263/60279024.py:8: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['age'].fillna(method="ffill",inplace=True)
# /var/folders/dg/k946k57108n2bklvf_jw_3y80000gq/T/ipykernel_34263/60279024.py:8: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df['age'].fillna(method="ffill",inplace=True)

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# 결측치 시각화를 위한 히트맵

df = pd.read_csv("csv_files/combined_customers.csv")
df['age'].interpolate(inplace=True)
plt.figure(figsize=(8, 4))
sns.heatmap(df.isnull(), cbar=True, cmap='viridis')
plt.title('missing values')
plt.show()
# Out:
# /var/folders/dg/k946k57108n2bklvf_jw_3y80000gq/T/ipykernel_34263/2077728056.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['age'].interpolate(inplace=True)

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# 결측치 시각화를 위한 히트맵

df = pd.read_csv("csv_files/combined_customers.csv")
df.dropna(axis=0, thresh=4, inplace=True)
plt.figure(figsize=(8, 4))
sns.heatmap(df.isnull(), cbar=True, cmap='viridis')
plt.title('missing values')
plt.show()
